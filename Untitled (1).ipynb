# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Copy of Shark Tank India Dataset.csv')

# %%
df
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df['deal'].value_counts()
# Out:
# 1    65
# 0    52
# Name: deal, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
df['deal'].value_counts().plot(autopct='%.2f%%',kind='pie')
# Out:
# <AxesSubplot:ylabel='deal'>

# %% [markdown]
# # most expensive dealing episode

# %%
A=df.groupby(df['episode_number'])['deal_amount'].sum().sort_values(ascending=False).reset_index()

# %%
A
# Out:
#     episode_number  deal_amount
# 0               17    280.00000
# 1               13    255.00000
# 2               16    170.00000
# 3               21    160.00000
# 4               28    150.00000
# 5               25    150.00000
# 6                6    150.00000
# 7               20    140.00000
# 8                1    140.00000
# 9                8    136.00000
# 10              15    125.00005
# 11               4    125.00000
# 12              12    115.00000
# 13              26    115.00000
# 14              33    110.00000
# 15              27    100.00101
# 16               9    100.00000
# 17              14    100.00000
# 18               7    100.00000
# 19               5    100.00000
# 20               3     95.00000
# 21              10     85.00000
# 22              11     80.00000
# 23              30     80.00000
# 24              29     75.00000
# 25              31     75.00000
# 26               2     70.00000
# 27              24     60.00000
# ...

# %% [markdown]
# ## All shark in

# %%
for i in df[df['total_sharks_invested']==5]:
    print(i)
# Out:
# episode_number
# pitch_number
# brand_name
# idea
# deal
# pitcher_ask_amount
# ask_equity
# ask_valuation
# deal_amount
# deal_equity
# deal_valuation
# ashneer_present
# anupam_present
# aman_present
# namita_present
# vineeta_present
# peyush_present
# ghazal_present
# ashneer_deal
# anupam_deal
# aman_deal
# namita_deal
# vineeta_deal
# peyush_deal
# ghazal_deal
# total_sharks_invested
# amount_per_shark
# equity_per_shark

# %%
df['total_sharks_invested'].value_counts()
# Out:
# 0    52
# 1    22
# 2    20
# 3    14
# 4     5
# 5     4
# Name: total_sharks_invested, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title('Maximum Sharks in')
plt.bar(df['episode_number'],df['total_sharks_invested'])
plt.xticks(df['episode_number'].unique());

# %%
df[df['total_sharks_invested']==5]
# Out:
#     episode_number  pitch_number             brand_name                 idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 15     1                45.0         5.0          900.0        100.0
# 49     1                50.0        10.0          500.0         50.0
# 63     1                50.0         2.0         2500.0        100.0
# 79     1               100.0         2.0         5000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 15         15.0  ...             1            1          1            1
# 49         25.0  ...             1            1          1            1
# ...

# %% [markdown]
# # No deals

# %%
df.iloc[np.where(df["pitcher_ask_amount"]==max(df["pitcher_ask_amount"])) and np.where(df["deal_amount"]==min(df["deal_amount"]))]
# Out:
#      episode_number  pitch_number                 brand_name  \
# 4                 2             5             Head and Heart
# 5                 2             6               Agro tourism
# 6                 3             7                Qzense Labs
# 10                4            11               JhaJi Achaar
# 13                5            14               Hungry Heads
# 14                5            15         Shrawani Engineers
# 17                6            18                    Hecolll
# 19                7            20                   Torch-it
# 20                7            21              La Kheer Deli
# 26                9            27            Kabira Handmade
# 30               11            31                 Gopal's 56
# 34               12            35                   SweeDesi
# 40               14            41         Morikko Pure Foods
# 41               14            42       Good Good Piggy Bank
# ...

# %%
df.groupby(['pitcher_ask_amount']).min()
# Out:
#                     episode_number  pitch_number  \
# pitcher_ask_amount
# 0.00101                         27            86
# 5.00000                         15            45
# 10.00000                         5            15
# 15.00000                        19            58
# 20.00000                        24            78
# 25.00000                         1             3
# 30.00000                         8            24
# 35.00000                        20            63
# 40.00000                         1             2
# 45.00000                         6            16
# 47.00000                        21            66
# 50.00000                         1             1
# 56.00000                         8            23
# 60.00000                        22            68
# 65.00000                        20            62
# 70.00000                         2             4
# 75.00000                         3             8
# 80.00000                        16            46
# ...

# %% [markdown]
# ## Ashneer deals

# %%
ash_grover = df[df['ashneer_deal']==1]
ash_grover
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 1                 1             2          Booz scooters
# 3                 2             4             Tagz Foods
# 15                6            16            Skippi Pops
# 18                7            19     Raising Superstars
# 21                8            22           Beyond Snack
# 23                8            24          Motion Breeze
# 29               10            30              EventBeep
# 38               13            39        The Yarn Bazaar
# 45               16            46           Bamboo India
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 55               18            56                   Otua
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# ...
